# %% [markdown]
# ## Harjoitustyö

# %% [markdown]
# ## Vaihe 1

# %% [markdown]
# #### Tehtävä 1. Hae Digitrafficin REST-rajapintapalvelusta (JSON-formaatissa) aktiiviset junat pääteosoitteella `/live-trains` Helsingin asemalta, joiden hakuparametrit ovat seuraavat:
# * arrived_trains=10
# * departed_trains=10
# * include_nonstopping=False

# %%
import requests

url = 'https://rata.digitraffic.fi/api/v1/live-trains/station/HKI?arrived_trains=10&departed_trains=10&include_nonstopping=False'
req_juna = requests.get(url=url)
req_juna.url
req_juna.status_code
juna_data = req_juna.json()
#juna_data

# %% [markdown]
# #### Tehtävä 2. Tämän jälkeen lue kyseinen data Pandasin dataframeen ilman muokkaamista, jolloin sarakkeiden otsikot ovat seuraavanlaiset:
#
#  `cancelled`,
#  `commuterLineID`,
#  `departureDate`,
#  `operatorShortCode`,
#  `operatorUICCode`,
#  `runningCurrently`,
#  `timeTableRows`,
#  `timetableAcceptanceDate`,
#  `timetableType`,
#  `trainCategory`,
#  `trainNumber`,
#  `trainType`,
#  `version`

# %%
import pandas as pd

junat_df = pd.DataFrame(juna_data)
junat_df
# Out:
#     trainNumber departureDate  operatorUICCode operatorShortCode trainType  \
# 0            27    2023-10-14               10                vr        IC
# 1            46    2023-10-14               10                vr        IC
# 2            67    2023-10-14               10                vr         S
# 3           175    2023-10-14               10                vr        IC
# 4           956    2023-10-14               10                vr        IC
# 5          8112    2023-10-14               10                vr        HL
# 6          8117    2023-10-14               10                vr        HL
# 7          8123    2023-10-14               10                vr        HL
# 8          8352    2023-10-14               10                vr        HL
# 9          8355    2023-10-14               10                vr        HL
# 10         8466    2023-10-14               10                vr        HL
# 11         8471    2023-10-14               10                vr        HL
# 12         8666    2023-10-14               10                vr        HL
# 13         8669    2023-10-14               10                vr        HL
# 14         8674    2023-10-14               10                vr        HL
# 15         8675    2023-10-14               10                vr        HL
# 16         8677    2023-10-14               10                vr        HL
# 17         8861    2023-10-14               10                vr        HL
# 18         8862    2023-10-14               10                vr        HL
# 19         8864    2023-10-14               10                vr        HL
# 20         8870    2023-10-14               10                vr        HL
# 21         8873    2023-10-14               10                vr        HL
# 22         9134    2023-10-14               10                vr        HL
# 23         9140    2023-10-14               10                vr        HL
# 24         9163    2023-10-14               10                vr        HL
# 25         9670    2023-10-14               10                vr        HL
# 26         9681    2023-10-14               10                vr        HL
# 27         9836    2023-10-14               10                vr        HL
# 28        65102    2023-10-14               10                vr       SAA
# 29        65103    2023-10-14               10                vr       SAA
#
#     trainCategory commuterLineID  runningCurrently  cancelled       version  \
# 0   Long-distance                             True      False  286685778667
# 1   Long-distance                             True      False  286685802268
# 2   Long-distance                             True      False  286685799533
# 3   Long-distance                             True      False  286685797517
# 4   Long-distance                            False      False  286685802267
# 5        Commuter              A             False      False  286685721913
# 6        Commuter              A             False      False  286685759834
# 7        Commuter              A             False      False  286666477271
# 8        Commuter              E              True      False  286685802268
# 9        Commuter              E             False      False  286668968694
# 10       Commuter              U             False      False  286685749421
# 11       Commuter              U              True      False  286685795456
# 12       Commuter              P             False      False  286685736936
# 13       Commuter              P              True      False  286685802267
# 14       Commuter              P              True      False  286685795456
# 15       Commuter              P              True      False  286685797518
# 16       Commuter              P             False      False  286685748937
# 17       Commuter              I             False      False  286685704051
# 18       Commuter              I             False      False  286685760252
# 19       Commuter              I              True      False  286685789498
# 20       Commuter              I              True      False  286685800251
# 21       Commuter              I             False      False  286680797320
# 22       Commuter              K             False      False  286685682533
# 23       Commuter              K              True      False  286685792243
# 24       Commuter              K              True      False  286685776992
# 25       Commuter              R             False      False  286685798977
# 26       Commuter              R              True      False  286685784164
# 27       Commuter              Z             False      False  286685754834
# 28       Shunting                            False      False  286685759834
# 29       Shunting                            False      False  286685475902
#
#    timetableType   timetableAcceptanceDate  \
# 0        REGULAR  2023-07-05T11:22:01.000Z
# 1        REGULAR  2023-07-05T11:22:01.000Z
# 2        REGULAR  2023-07-05T11:22:01.000Z
# 3        REGULAR  2023-07-05T11:22:01.000Z
# 4        REGULAR  2023-02-16T07:07:26.000Z
# 5        REGULAR  2023-05-11T05:02:32.000Z
# 6        REGULAR  2022-12-15T06:04:43.000Z
# 7        REGULAR  2023-05-11T05:02:32.000Z
# 8        REGULAR  2022-12-15T06:04:43.000Z
# 9        REGULAR  2022-12-15T06:04:43.000Z
# 10       REGULAR  2023-07-05T11:22:01.000Z
# 11       REGULAR  2023-07-05T11:22:01.000Z
# 12       REGULAR  2023-07-05T11:22:01.000Z
# 13       REGULAR  2023-07-05T11:22:01.000Z
# 14       REGULAR  2023-07-05T11:22:01.000Z
# 15       REGULAR  2023-07-05T11:22:01.000Z
# 16       REGULAR  2023-07-05T11:22:01.000Z
# 17       REGULAR  2023-07-05T11:22:01.000Z
# 18       REGULAR  2023-07-05T11:22:01.000Z
# 19       REGULAR  2023-07-05T11:22:01.000Z
# 20       REGULAR  2023-07-05T11:22:01.000Z
# 21       REGULAR  2023-07-05T11:22:01.000Z
# 22       REGULAR  2023-07-05T11:22:01.000Z
# 23       REGULAR  2023-07-05T11:22:01.000Z
# 24       REGULAR  2023-07-05T11:22:01.000Z
# 25       REGULAR  2023-05-11T05:02:32.000Z
# 26       REGULAR  2023-05-11T05:02:32.000Z
# 27       REGULAR  2023-05-11T05:02:32.000Z
# 28         ADHOC  2023-10-14T09:35:28.000Z
# 29         ADHOC  2023-10-14T09:36:20.000Z
#
#                                         timeTableRows
# 0   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 1   [{'stationShortCode': 'VS', 'stationUICCode': ...
# 2   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 3   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 4   [{'stationShortCode': 'KUT', 'stationUICCode':...
# 5   [{'stationShortCode': 'LPV', 'stationUICCode':...
# 6   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 7   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 8   [{'stationShortCode': 'KLH', 'stationUICCode':...
# 9   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10  [{'stationShortCode': 'KKN', 'stationUICCode':...
# 11  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17  [{'stationShortCode': 'LEN', 'stationUICCode':...
# 18  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 19  [{'stationShortCode': 'LEN', 'stationUICCode':...
# 20  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 21  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 22  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 23  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 24  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 25  [{'stationShortCode': 'RI', 'stationUICCode': ...
# 26  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 27  [{'stationShortCode': 'LH', 'stationUICCode': ...
# 28  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29  [{'stationShortCode': 'HKI', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 3. Poista kaikki muut sarakkeet paitsi `timeTableRows` ja `trainNumber`

# %%
train_info = junat_df.drop(["cancelled", "commuterLineID", "departureDate", 
                     "operatorShortCode", "operatorUICCode", "runningCurrently", 
                     "timetableAcceptanceDate", "timetableType", "trainCategory", 
                     "trainType", "version"], axis=1)
train_info
# Out:
#     trainNumber                                      timeTableRows
# 0            27  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 1            46  [{'stationShortCode': 'VS', 'stationUICCode': ...
# 2            67  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 3           175  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 4           956  [{'stationShortCode': 'KUT', 'stationUICCode':...
# 5          8112  [{'stationShortCode': 'LPV', 'stationUICCode':...
# 6          8117  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 7          8123  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 8          8352  [{'stationShortCode': 'KLH', 'stationUICCode':...
# 9          8355  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10         8466  [{'stationShortCode': 'KKN', 'stationUICCode':...
# 11         8471  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12         8666  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13         8669  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14         8674  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15         8675  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16         8677  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17         8861  [{'stationShortCode': 'LEN', 'stationUICCode':...
# 18         8862  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 19         8864  [{'stationShortCode': 'LEN', 'stationUICCode':...
# 20         8870  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 21         8873  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 22         9134  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 23         9140  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 24         9163  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 25         9670  [{'stationShortCode': 'RI', 'stationUICCode': ...
# 26         9681  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 27         9836  [{'stationShortCode': 'LH', 'stationUICCode': ...
# 28        65102  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29        65103  [{'stationShortCode': 'HKI', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 4. Tämän jälkeen pura `timeTableRows` sarakkeen arvot jokaisesta junasta erikseen (sarakkeen arvo jokaiselle junalle sisältää useampia JSON-objekteja) ja lisää dataan mukaan junan tiedot yksilöivä `trainNumber`

# %%
from pandas import json_normalize

timetable_df = pd.DataFrame()

# Käy läpi alkuperäisen DataFrameen rivit
for index, row in junat_df.iterrows():
    train_number = row['trainNumber']
    time_table_rows = row['timeTableRows']
    
    # Purkaa JSON-tiedot ja lisää ne uuteen DataFrameen
    train_df = json_normalize(time_table_rows)
    train_df['trainNumber'] = train_number
    
    timetable_df = pd.concat([timetable_df, train_df], ignore_index=True)
timetable_df
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1651              HKI               1          FI    ARRIVAL           True
# 1652              HKI               1          FI  DEPARTURE           True
# 1653              PSL              10          FI    ARRIVAL          False
# 1654              PSL              10          FI  DEPARTURE          False
# 1655              ILR            1030          FI    ARRIVAL           True
#
#      commercialStop commercialTrack  cancelled             scheduledTime  \
# 0              True               7      False  2023-10-14T11:20:00.000Z
# 1              True               3      False  2023-10-14T11:25:00.000Z
# 2              True               3      False  2023-10-14T11:26:00.000Z
# 3               NaN                      False  2023-10-14T11:28:00.000Z
# 4               NaN                      False  2023-10-14T11:28:00.000Z
# ...             ...             ...        ...                       ...
# 1651           True               6      False  2023-10-14T11:21:00.000Z
# 1652           True               8      False  2023-10-14T11:32:00.000Z
# 1653            NaN                      False  2023-10-14T11:36:00.000Z
# 1654            NaN                      False  2023-10-14T11:36:00.000Z
# 1655           True             755      False  2023-10-14T11:46:00.000Z
#
#                     actualTime  differenceInMinutes causes  trainNumber  \
# 0     2023-10-14T11:20:44.000Z                  1.0     []           27
# 1                          NaN                  0.0     []           27
# 2                          NaN                  0.0     []           27
# 3                          NaN                  0.0     []           27
# 4                          NaN                  0.0     []           27
# ...                        ...                  ...    ...          ...
# 1651  2023-10-14T11:19:43.000Z                 -1.0     []        65102
# 1652                       NaN                  NaN     []        65103
# 1653                       NaN                  NaN     []        65103
# 1654                       NaN                  NaN     []        65103
# 1655                       NaN                  NaN     []        65103
#
#      trainReady.source trainReady.accepted      trainReady.timestamp  \
# 0                KUPLA                True  2023-10-14T11:09:28.000Z
# 1                  NaN                 NaN                       NaN
# 2                  NaN                 NaN                       NaN
# 3                  NaN                 NaN                       NaN
# 4                  NaN                 NaN                       NaN
# ...                ...                 ...                       ...
# 1651               NaN                 NaN                       NaN
# 1652               NaN                 NaN                       NaN
# 1653               NaN                 NaN                       NaN
# 1654               NaN                 NaN                       NaN
# 1655               NaN                 NaN                       NaN
#
#               liveEstimateTime estimateSource
# 0                          NaN            NaN
# 1     2023-10-14T11:25:09.000Z      COMBOCALC
# 2     2023-10-14T11:26:09.000Z      COMBOCALC
# 3     2023-10-14T11:28:16.000Z      COMBOCALC
# 4     2023-10-14T11:28:16.000Z      COMBOCALC
# ...                        ...            ...
# 1651                       NaN            NaN
# 1652                       NaN            NaN
# 1653                       NaN            NaN
# 1654                       NaN            NaN
# 1655                       NaN            NaN
#
# [1656 rows x 18 columns]

# %% [markdown]
# #### Tehtävä 5. Pudota sitten seuraavat sarakkeet datasta: `causes`, `differenceInMinutes` ja `commercialStop`

# %%
new_timetable_df = timetable_df.drop(["causes","differenceInMinutes","commercialStop"], axis=1)
new_timetable_df
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1651              HKI               1          FI    ARRIVAL           True
# 1652              HKI               1          FI  DEPARTURE           True
# 1653              PSL              10          FI    ARRIVAL          False
# 1654              PSL              10          FI  DEPARTURE          False
# 1655              ILR            1030          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  7      False  2023-10-14T11:20:00.000Z
# 1                  3      False  2023-10-14T11:25:00.000Z
# 2                  3      False  2023-10-14T11:26:00.000Z
# 3                         False  2023-10-14T11:28:00.000Z
# 4                         False  2023-10-14T11:28:00.000Z
# ...              ...        ...                       ...
# 1651               6      False  2023-10-14T11:21:00.000Z
# 1652               8      False  2023-10-14T11:32:00.000Z
# 1653                      False  2023-10-14T11:36:00.000Z
# 1654                      False  2023-10-14T11:36:00.000Z
# 1655             755      False  2023-10-14T11:46:00.000Z
#
#                     actualTime  trainNumber trainReady.source  \
# 0     2023-10-14T11:20:44.000Z           27             KUPLA
# 1                          NaN           27               NaN
# 2                          NaN           27               NaN
# 3                          NaN           27               NaN
# 4                          NaN           27               NaN
# ...                        ...          ...               ...
# 1651  2023-10-14T11:19:43.000Z        65102               NaN
# 1652                       NaN        65103               NaN
# 1653                       NaN        65103               NaN
# 1654                       NaN        65103               NaN
# 1655                       NaN        65103               NaN
#
#      trainReady.accepted      trainReady.timestamp          liveEstimateTime  \
# 0                   True  2023-10-14T11:09:28.000Z                       NaN
# 1                    NaN                       NaN  2023-10-14T11:25:09.000Z
# 2                    NaN                       NaN  2023-10-14T11:26:09.000Z
# 3                    NaN                       NaN  2023-10-14T11:28:16.000Z
# 4                    NaN                       NaN  2023-10-14T11:28:16.000Z
# ...                  ...                       ...                       ...
# 1651                 NaN                       NaN                       NaN
# 1652                 NaN                       NaN                       NaN
# 1653                 NaN                       NaN                       NaN
# 1654                 NaN                       NaN                       NaN
# 1655                 NaN                       NaN                       NaN
#
#      estimateSource
# 0               NaN
# 1         COMBOCALC
# 2         COMBOCALC
# 3         COMBOCALC
# 4         COMBOCALC
# ...             ...
# 1651            NaN
# 1652            NaN
# 1653            NaN
# 1654            NaN
# 1655            NaN
#
# [1656 rows x 15 columns]

# %% [markdown]
# #### Tehtävä 6. Täytä jokaisen rivin sarakkeen `actualTime` puuttuvat arvot `scheduledTime` -sarakkeen arvolla.

# %%
new_timetable_df['actualTime'].fillna(new_timetable_df['scheduledTime'], inplace=True)
new_timetable_df
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1651              HKI               1          FI    ARRIVAL           True
# 1652              HKI               1          FI  DEPARTURE           True
# 1653              PSL              10          FI    ARRIVAL          False
# 1654              PSL              10          FI  DEPARTURE          False
# 1655              ILR            1030          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  7      False  2023-10-14T11:20:00.000Z
# 1                  3      False  2023-10-14T11:25:00.000Z
# 2                  3      False  2023-10-14T11:26:00.000Z
# 3                         False  2023-10-14T11:28:00.000Z
# 4                         False  2023-10-14T11:28:00.000Z
# ...              ...        ...                       ...
# 1651               6      False  2023-10-14T11:21:00.000Z
# 1652               8      False  2023-10-14T11:32:00.000Z
# 1653                      False  2023-10-14T11:36:00.000Z
# 1654                      False  2023-10-14T11:36:00.000Z
# 1655             755      False  2023-10-14T11:46:00.000Z
#
#                     actualTime  trainNumber trainReady.source  \
# 0     2023-10-14T11:20:44.000Z           27             KUPLA
# 1     2023-10-14T11:25:00.000Z           27               NaN
# 2     2023-10-14T11:26:00.000Z           27               NaN
# 3     2023-10-14T11:28:00.000Z           27               NaN
# 4     2023-10-14T11:28:00.000Z           27               NaN
# ...                        ...          ...               ...
# 1651  2023-10-14T11:19:43.000Z        65102               NaN
# 1652  2023-10-14T11:32:00.000Z        65103               NaN
# 1653  2023-10-14T11:36:00.000Z        65103               NaN
# 1654  2023-10-14T11:36:00.000Z        65103               NaN
# 1655  2023-10-14T11:46:00.000Z        65103               NaN
#
#      trainReady.accepted      trainReady.timestamp          liveEstimateTime  \
# 0                   True  2023-10-14T11:09:28.000Z                       NaN
# 1                    NaN                       NaN  2023-10-14T11:25:09.000Z
# 2                    NaN                       NaN  2023-10-14T11:26:09.000Z
# 3                    NaN                       NaN  2023-10-14T11:28:16.000Z
# 4                    NaN                       NaN  2023-10-14T11:28:16.000Z
# ...                  ...                       ...                       ...
# 1651                 NaN                       NaN                       NaN
# 1652                 NaN                       NaN                       NaN
# 1653                 NaN                       NaN                       NaN
# 1654                 NaN                       NaN                       NaN
# 1655                 NaN                       NaN                       NaN
#
#      estimateSource
# 0               NaN
# 1         COMBOCALC
# 2         COMBOCALC
# 3         COMBOCALC
# 4         COMBOCALC
# ...             ...
# 1651            NaN
# 1652            NaN
# 1653            NaN
# 1654            NaN
# 1655            NaN
#
# [1656 rows x 15 columns]

# %% [markdown]
# ## Vaihe 2
#
# #### Tehtävä 7. Pura tämän kansion sisällä olevan `data.html` -tiedoston `table`-elementin solujen arvot käyttäen regex-syntaksia ja yhdistä ne vaiheessa 1 luotuun dataframeen. Huom: tehtävässä tulee käyttää vain regexiä (Esim. Pandasin read_html()-metodin käyttö on kielletty)!

# %%
import re

with open('data.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

#patternit
table_pattern = r'<table.*?>(.*?)</table>'
cell_pattern = r'<td.*?>(.*?)</td>'

table_match = re.search(table_pattern, html_content, re.DOTALL)
if table_match:
    table_html = table_match.group(1)
    cell_matches = re.findall(cell_pattern, table_html, re.DOTALL)

    
    columns = ["actualTime", "cancelled", "commercialTrack", 
               "countryCode", "scheduledTime", "stationShortCode", 
               "stationUICCode", "trainStopping", "type", "trainNumber"]
    df = pd.DataFrame(columns=columns)

    
    num_columns = len(columns)
    num_cells = len(cell_matches)
    
    for i in range(num_rows):
        df = pd.concat([df, pd.DataFrame([cell_data], columns=columns)], ignore_index=True)

    
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 25
#      22     num_columns = len(columns)
#      23     num_cells = len(cell_matches)
# ---> 25     for i in range(num_rows):
#      26         df = pd.concat([df, pd.DataFrame([cell_data], columns=columns)], ignore_index=True)
#      29 df
#
# NameError: name 'num_rows' is not defined

# %% [markdown]
# ## Vaihe 3
#
# #### Tehtävä 8. Tee SQLite tietokanta ja lisää sinne vaiheen 2 tuloksena saatu dataframe.

# %%
import sqlite3


harkka_base = sqlite3.connect("harkka.db")

# %%
connection = testi_base.cursor()

# %%
df_to_sql = df.copy()
df_to_sql.to_sql(name="harkka.db", con=harkka_base, if_exists='replace', index=False)
df_to_sql

# %%
harkka_base.close()
