# %% [markdown]
# ## Harjoitustyö

# %% [markdown]
# ## Vaihe 1

# %% [markdown]
# #### Tehtävä 1. Hae Digitrafficin REST-rajapintapalvelusta (JSON-formaatissa) aktiiviset junat pääteosoitteella `/live-trains` Helsingin asemalta, joiden hakuparametrit ovat seuraavat:
# * arrived_trains=10
# * departed_trains=10
# * include_nonstopping=False

# %%
import requests

url = 'https://rata.digitraffic.fi/api/v1/live-trains/station/HKI?arrived_trains=10&departed_trains=10&include_nonstopping=False'
req_juna = requests.get(url=url)
req_juna.url
req_juna.status_code
juna_data = req_juna.json()
#juna_data

# %% [markdown]
# #### Tehtävä 2. Tämän jälkeen lue kyseinen data Pandasin dataframeen ilman muokkaamista, jolloin sarakkeiden otsikot ovat seuraavanlaiset:
#
#  `cancelled`,
#  `commuterLineID`,
#  `departureDate`,
#  `operatorShortCode`,
#  `operatorUICCode`,
#  `runningCurrently`,
#  `timeTableRows`,
#  `timetableAcceptanceDate`,
#  `timetableType`,
#  `trainCategory`,
#  `trainNumber`,
#  `trainType`,
#  `version`

# %%
import pandas as pd

junat_df = pd.DataFrame(juna_data)
junat_df
# Out:
#     trainNumber departureDate  operatorUICCode operatorShortCode trainType  \
# 0             7    2025-01-29               10                vr        IC
# 1            47    2025-01-29               10                vr        IC
# 2          8124    2025-01-29               10                vr        HL
# 3          8126    2025-01-29               10                vr        HL
# 4          8131    2025-01-29               10                vr        HL
# 5          8133    2025-01-29               10                vr        HL
# 6          8359    2025-01-29               10                vr        HL
# 7          8474    2025-01-29               10                vr        HL
# 8          8479    2025-01-29               10                vr        HL
# 9          8587    2025-01-29               10                vr        HL
# 10         8680    2025-01-29               10                vr        HL
# 11         8681    2025-01-29               10                vr        HL
# 12         8683    2025-01-29               10                vr        HL
# 13         8688    2025-01-29               10                vr        HL
# 14         8689    2025-01-29               10                vr        HL
# 15         8881    2025-01-29               10                vr        HL
# 16         8883    2025-01-29               10                vr        HL
# 17         8888    2025-01-29               10                vr        HL
# 18         8889    2025-01-29               10                vr        HL
# 19         8891    2025-01-29               10                vr        HL
# 20         9210    2025-01-29               10                vr        HL
# 21         9214    2025-01-29               10                vr        HL
# 22         9233    2025-01-29               10                vr        HL
# 23         9237    2025-01-29               10                vr        HL
# 24         9676    2025-01-29               10                vr        HL
# 25         9687    2025-01-29               10                vr        HL
# 26         9840    2025-01-29               10                vr        HL
# 27        64120    2025-01-29               10                vr         W
# 28        64420    2025-01-29               10                vr         W
# 29        64422    2025-01-29               10                vr         W
#
#     trainCategory commuterLineID  runningCurrently  cancelled       version  \
# 0   Long-distance                             True      False  290367393861
# 1   Long-distance                            False      False  290367328034
# 2        Commuter              A             False      False  290367327670
# 3        Commuter              A             False      False  290367394470
# 4        Commuter              A              True      False  290367398111
# 5        Commuter              A             False      False  290367286313
# 6        Commuter              E             False      False  290365654590
# 7        Commuter              U             False      False  290367366483
# 8        Commuter              U              True      False  290367396380
# 9        Commuter              Y             False      False  290367364721
# 10       Commuter              P             False      False  290367307526
# 11       Commuter              P              True      False  290367376170
# 12       Commuter              P              True      False  290367397321
# 13       Commuter              P              True      False  290367394470
# 14       Commuter              P              True      False  290367392495
# 15       Commuter              I             False      False  290367369444
# 16       Commuter              I              True      False  290367393861
# 17       Commuter              I              True      False  290367398111
# 18       Commuter              I              True      False  290367390635
# 19       Commuter              I             False      False  290367395987
# 20       Commuter              K             False      False  290367360186
# 21       Commuter              K              True      False  290367391969
# 22       Commuter              K              True      False  290367390635
# 23       Commuter              K              True      False  290367391417
# 24       Commuter              R             False      False  290367366483
# 25       Commuter              R              True      False  290367398111
# 26       Commuter              Z              True      False  290367379352
# 27       Shunting                            False      False  290367298823
# 28       Shunting                            False      False  290367364721
# 29       Shunting                            False      False  290367394897
#
#    timetableType   timetableAcceptanceDate  \
# 0        REGULAR  2024-10-31T06:14:29.000Z
# 1        REGULAR  2024-10-31T06:14:29.000Z
# 2        REGULAR  2024-10-31T06:14:29.000Z
# 3        REGULAR  2024-10-31T06:14:29.000Z
# 4        REGULAR  2024-10-31T06:14:29.000Z
# 5        REGULAR  2024-10-31T06:14:29.000Z
# 6        REGULAR  2024-10-31T06:14:29.000Z
# 7        REGULAR  2024-10-31T06:14:29.000Z
# 8        REGULAR  2024-10-31T06:14:29.000Z
# 9        REGULAR  2024-10-31T06:14:29.000Z
# 10       REGULAR  2024-10-31T06:14:29.000Z
# 11       REGULAR  2024-10-31T06:14:29.000Z
# 12       REGULAR  2024-10-31T06:14:29.000Z
# 13       REGULAR  2024-10-31T06:14:29.000Z
# 14       REGULAR  2024-10-31T06:14:29.000Z
# 15       REGULAR  2024-10-31T06:14:29.000Z
# 16       REGULAR  2024-10-31T06:14:29.000Z
# 17       REGULAR  2024-10-31T06:14:29.000Z
# 18       REGULAR  2024-10-31T06:14:29.000Z
# 19       REGULAR  2024-10-31T06:14:29.000Z
# 20       REGULAR  2024-10-31T06:14:29.000Z
# 21       REGULAR  2024-10-31T06:14:29.000Z
# 22       REGULAR  2024-10-31T06:14:29.000Z
# 23       REGULAR  2024-10-31T06:14:29.000Z
# 24       REGULAR  2024-08-16T07:34:07.000Z
# 25       REGULAR  2024-08-16T07:34:07.000Z
# 26       REGULAR  2024-08-16T07:34:07.000Z
# 27       REGULAR  2024-10-31T06:14:29.000Z
# 28       REGULAR  2024-10-31T06:14:29.000Z
# 29       REGULAR  2024-10-31T06:14:29.000Z
#
#                                         timeTableRows
# 0   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 1   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 2   [{'stationShortCode': 'LPV', 'stationUICCode':...
# 3   [{'stationShortCode': 'LPV', 'stationUICCode':...
# 4   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 5   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 6   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 7   [{'stationShortCode': 'KKN', 'stationUICCode':...
# 8   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 9   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 11  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 18  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 19  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 20  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 21  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 22  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 23  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 24  [{'stationShortCode': 'RI', 'stationUICCode': ...
# 25  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 26  [{'stationShortCode': 'LH', 'stationUICCode': ...
# 27  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 28  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29  [{'stationShortCode': 'ILR', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 3. Poista kaikki muut sarakkeet paitsi `timeTableRows` ja `trainNumber`

# %%
train_info = junat_df.drop(["cancelled", "commuterLineID", "departureDate", 
                     "operatorShortCode", "operatorUICCode", "runningCurrently", 
                     "timetableAcceptanceDate", "timetableType", "trainCategory", 
                     "trainType", "version"], axis=1)
train_info
# Out:
#     trainNumber                                      timeTableRows
# 0             7  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 1            47  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 2          8124  [{'stationShortCode': 'LPV', 'stationUICCode':...
# 3          8126  [{'stationShortCode': 'LPV', 'stationUICCode':...
# 4          8131  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 5          8133  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 6          8359  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 7          8474  [{'stationShortCode': 'KKN', 'stationUICCode':...
# 8          8479  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 9          8587  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10         8680  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 11         8681  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12         8683  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13         8688  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14         8689  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15         8881  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16         8883  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17         8888  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 18         8889  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 19         8891  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 20         9210  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 21         9214  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 22         9233  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 23         9237  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 24         9676  [{'stationShortCode': 'RI', 'stationUICCode': ...
# 25         9687  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 26         9840  [{'stationShortCode': 'LH', 'stationUICCode': ...
# 27        64120  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 28        64420  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29        64422  [{'stationShortCode': 'ILR', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 4. Tämän jälkeen pura `timeTableRows` sarakkeen arvot jokaisesta junasta erikseen (sarakkeen arvo jokaiselle junalle sisältää useampia JSON-objekteja) ja lisää dataan mukaan junan tiedot yksilöivä `trainNumber`

# %%
from pandas import json_normalize

timetable_df = pd.DataFrame()

# Käy läpi alkuperäisen DataFrameen rivit
for index, row in junat_df.iterrows():
    train_number = row['trainNumber']
    time_table_rows = row['timeTableRows']
    
    # Purkaa JSON-tiedot ja lisää ne uuteen DataFrameen
    train_df = json_normalize(time_table_rows)
    train_df['trainNumber'] = train_number
    
    timetable_df = pd.concat([timetable_df, train_df], ignore_index=True)
timetable_df
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1449              HKI               1          FI    ARRIVAL           True
# 1450              ILR            1030          FI  DEPARTURE           True
# 1451              PSL              10          FI    ARRIVAL          False
# 1452              PSL              10          FI  DEPARTURE          False
# 1453              HKI               1          FI    ARRIVAL           True
#
#      commercialStop commercialTrack  cancelled             scheduledTime  \
# 0              True               9      False  2025-01-29T13:19:00.000Z
# 1              True               4      False  2025-01-29T13:24:00.000Z
# 2              True               4      False  2025-01-29T13:25:00.000Z
# 3               NaN                      False  2025-01-29T13:27:00.000Z
# 4               NaN                      False  2025-01-29T13:27:00.000Z
# ...             ...             ...        ...                       ...
# 1449           True              10      False  2025-01-29T13:20:00.000Z
# 1450           True             797      False  2025-01-29T13:11:00.000Z
# 1451            NaN               7      False  2025-01-29T13:21:00.000Z
# 1452            NaN               7      False  2025-01-29T13:21:00.000Z
# 1453           True               9      False  2025-01-29T13:26:00.000Z
#
#                     actualTime  differenceInMinutes causes trainReady.source  \
# 0     2025-01-29T13:19:16.000Z                  0.0     []             KUPLA
# 1                          NaN                  0.0     []               NaN
# 2                          NaN                  0.0     []               NaN
# 3                          NaN                  0.0     []               NaN
# 4                          NaN                  0.0     []               NaN
# ...                        ...                  ...    ...               ...
# 1449  2025-01-29T13:18:32.000Z                 -1.0     []               NaN
# 1450  2025-01-29T13:12:02.000Z                  1.0     []               NaN
# 1451  2025-01-29T13:16:19.000Z                 -5.0     []               NaN
# 1452  2025-01-29T13:16:19.000Z                 -5.0     []               NaN
# 1453  2025-01-29T13:23:00.000Z                 -3.0     []               NaN
#
#      trainReady.accepted      trainReady.timestamp          liveEstimateTime  \
# 0                   True  2025-01-29T13:04:24.000Z                       NaN
# 1                    NaN                       NaN  2025-01-29T13:24:01.000Z
# 2                    NaN                       NaN  2025-01-29T13:25:01.000Z
# 3                    NaN                       NaN  2025-01-29T13:27:07.000Z
# 4                    NaN                       NaN  2025-01-29T13:27:07.000Z
# ...                  ...                       ...                       ...
# 1449                 NaN                       NaN                       NaN
# 1450                 NaN                       NaN                       NaN
# 1451                 NaN                       NaN                       NaN
# 1452                 NaN                       NaN                       NaN
# 1453                 NaN                       NaN                       NaN
#
#        estimateSource  trainNumber
# 0                 NaN            7
# 1     LIIKE_AUTOMATIC            7
# 2     LIIKE_AUTOMATIC            7
# 3     LIIKE_AUTOMATIC            7
# 4     LIIKE_AUTOMATIC            7
# ...               ...          ...
# 1449              NaN        64420
# 1450              NaN        64422
# 1451              NaN        64422
# 1452              NaN        64422
# 1453              NaN        64422
#
# [1454 rows x 18 columns]

# %% [markdown]
# #### Tehtävä 5. Pudota sitten seuraavat sarakkeet datasta: `causes`, `differenceInMinutes` ja `commercialStop`

# %%
new_timetable_df = timetable_df.drop(["causes","differenceInMinutes","commercialStop"], axis=1)
new_timetable_df
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1449              HKI               1          FI    ARRIVAL           True
# 1450              ILR            1030          FI  DEPARTURE           True
# 1451              PSL              10          FI    ARRIVAL          False
# 1452              PSL              10          FI  DEPARTURE          False
# 1453              HKI               1          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  9      False  2025-01-29T13:19:00.000Z
# 1                  4      False  2025-01-29T13:24:00.000Z
# 2                  4      False  2025-01-29T13:25:00.000Z
# 3                         False  2025-01-29T13:27:00.000Z
# 4                         False  2025-01-29T13:27:00.000Z
# ...              ...        ...                       ...
# 1449              10      False  2025-01-29T13:20:00.000Z
# 1450             797      False  2025-01-29T13:11:00.000Z
# 1451               7      False  2025-01-29T13:21:00.000Z
# 1452               7      False  2025-01-29T13:21:00.000Z
# 1453               9      False  2025-01-29T13:26:00.000Z
#
#                     actualTime trainReady.source trainReady.accepted  \
# 0     2025-01-29T13:19:16.000Z             KUPLA                True
# 1                          NaN               NaN                 NaN
# 2                          NaN               NaN                 NaN
# 3                          NaN               NaN                 NaN
# 4                          NaN               NaN                 NaN
# ...                        ...               ...                 ...
# 1449  2025-01-29T13:18:32.000Z               NaN                 NaN
# 1450  2025-01-29T13:12:02.000Z               NaN                 NaN
# 1451  2025-01-29T13:16:19.000Z               NaN                 NaN
# 1452  2025-01-29T13:16:19.000Z               NaN                 NaN
# 1453  2025-01-29T13:23:00.000Z               NaN                 NaN
#
#           trainReady.timestamp          liveEstimateTime   estimateSource  \
# 0     2025-01-29T13:04:24.000Z                       NaN              NaN
# 1                          NaN  2025-01-29T13:24:01.000Z  LIIKE_AUTOMATIC
# 2                          NaN  2025-01-29T13:25:01.000Z  LIIKE_AUTOMATIC
# 3                          NaN  2025-01-29T13:27:07.000Z  LIIKE_AUTOMATIC
# 4                          NaN  2025-01-29T13:27:07.000Z  LIIKE_AUTOMATIC
# ...                        ...                       ...              ...
# 1449                       NaN                       NaN              NaN
# 1450                       NaN                       NaN              NaN
# 1451                       NaN                       NaN              NaN
# 1452                       NaN                       NaN              NaN
# 1453                       NaN                       NaN              NaN
#
#       trainNumber
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7
# ...           ...
# 1449        64420
# 1450        64422
# 1451        64422
# 1452        64422
# 1453        64422
#
# [1454 rows x 15 columns]

# %% [markdown]
# #### Tehtävä 6. Täytä jokaisen rivin sarakkeen `actualTime` puuttuvat arvot `scheduledTime` -sarakkeen arvolla.

# %%
new_timetable_df['actualTime'].fillna(new_timetable_df['scheduledTime'], inplace=True)
new_timetable_df
# Out:
# C:\Users\katri\AppData\Local\Temp\ipykernel_32856\171462403.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_timetable_df['actualTime'].fillna(new_timetable_df['scheduledTime'], inplace=True)
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1449              HKI               1          FI    ARRIVAL           True
# 1450              ILR            1030          FI  DEPARTURE           True
# 1451              PSL              10          FI    ARRIVAL          False
# 1452              PSL              10          FI  DEPARTURE          False
# 1453              HKI               1          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  9      False  2025-01-29T13:19:00.000Z
# 1                  4      False  2025-01-29T13:24:00.000Z
# 2                  4      False  2025-01-29T13:25:00.000Z
# 3                         False  2025-01-29T13:27:00.000Z
# 4                         False  2025-01-29T13:27:00.000Z
# ...              ...        ...                       ...
# 1449              10      False  2025-01-29T13:20:00.000Z
# 1450             797      False  2025-01-29T13:11:00.000Z
# 1451               7      False  2025-01-29T13:21:00.000Z
# 1452               7      False  2025-01-29T13:21:00.000Z
# 1453               9      False  2025-01-29T13:26:00.000Z
#
#                     actualTime trainReady.source trainReady.accepted  \
# 0     2025-01-29T13:19:16.000Z             KUPLA                True
# 1     2025-01-29T13:24:00.000Z               NaN                 NaN
# 2     2025-01-29T13:25:00.000Z               NaN                 NaN
# 3     2025-01-29T13:27:00.000Z               NaN                 NaN
# 4     2025-01-29T13:27:00.000Z               NaN                 NaN
# ...                        ...               ...                 ...
# 1449  2025-01-29T13:18:32.000Z               NaN                 NaN
# 1450  2025-01-29T13:12:02.000Z               NaN                 NaN
# 1451  2025-01-29T13:16:19.000Z               NaN                 NaN
# 1452  2025-01-29T13:16:19.000Z               NaN                 NaN
# 1453  2025-01-29T13:23:00.000Z               NaN                 NaN
#
#           trainReady.timestamp          liveEstimateTime   estimateSource  \
# 0     2025-01-29T13:04:24.000Z                       NaN              NaN
# 1                          NaN  2025-01-29T13:24:01.000Z  LIIKE_AUTOMATIC
# 2                          NaN  2025-01-29T13:25:01.000Z  LIIKE_AUTOMATIC
# 3                          NaN  2025-01-29T13:27:07.000Z  LIIKE_AUTOMATIC
# 4                          NaN  2025-01-29T13:27:07.000Z  LIIKE_AUTOMATIC
# ...                        ...                       ...              ...
# 1449                       NaN                       NaN              NaN
# 1450                       NaN                       NaN              NaN
# 1451                       NaN                       NaN              NaN
# 1452                       NaN                       NaN              NaN
# 1453                       NaN                       NaN              NaN
#
#       trainNumber
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7
# ...           ...
# 1449        64420
# 1450        64422
# 1451        64422
# 1452        64422
# 1453        64422
#
# [1454 rows x 15 columns]

# %% [markdown]
# ## Vaihe 2
#
# #### Tehtävä 7. Pura tämän kansion sisällä olevan `data.html` -tiedoston `table`-elementin solujen arvot käyttäen regex-syntaksia ja yhdistä ne vaiheessa 1 luotuun dataframeen. Huom: tehtävässä tulee käyttää vain regexiä (Esim. Pandasin read_html()-metodin käyttö on kielletty)!

# %%
import re

with open('data.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

#patternit
table_pattern = r'<table.*?>(.*?)</table>'
cell_pattern = r'<td.*?>(.*?)</td>'

#määritellään ensin, miten haetaan
table_match = re.search(table_pattern, html_content, re.DOTALL)
if table_match:
    table_html = table_match.group(1)
    cell_matches = re.findall(cell_pattern, table_html, re.DOTALL)

    #tämän jälkeen, mitä haetaan
    columns = ["actualTime", "cancelled", "commercialTrack", 
               "countryCode", "scheduledTime", "stationShortCode", 
               "stationUICCode", "trainStopping", "type", "trainNumber"]

    
    num_columns = len(columns)
    num_cells = len(cell_matches)
    
    #ja vielä, mitä tehdään datalle, eli yhdistetään ne toisiinsa
    data_rows = [cell_matches[i:i + num_columns] for i in range(0, num_cells, num_columns)]
    df = pd.DataFrame(data_rows, columns=columns)

    
df
# Out:
#                                           actualTime  \
# 0  \n                        2019-08-06T04:48:00....
# 1  \n                        2019-08-06T06:04:39....
# 2  \n                        2019-08-06T07:03:12....
#
#                                            cancelled  \
# 0  \n                        False\n
# 1  \n                        False\n
# 2  \n                        False\n
#
#                                 commercialTrack  \
# 0  \n                        \n
# 1                          \n\n
# 2  \n                        \n
#
#                                       countryCode  \
# 0  \n                        FI\n
# 1  \n                        FI\n
# 2  \n                        FI\n
#
#                                        scheduledTime  \
# 0  \n                        2019-08-06T04:48:00....
# 1  \n                        2019-08-06T06:04:39....
# 2  \n                        2019-08-06T07:03:12....
#
#                                     stationShortCode  \
# 0  \n                        JVS\t\n
# 1   \n                        R702\n
# 2    \n                        ILA\n
#
#                                       stationUICCode  \
# 0   \n                        1272\n
# 1  \n                        98998\n
# 2  \n                        98998\n
#
#                                        trainStopping  \
# 0  \n                        False\n
# 1  \n                        False\n
# 2      \n                        9\n
#
#                                                 type  \
# 0  \n                        DEPARTURE\n         ...
# 1  \n                        ARRIVAL\n           ...
# 2  \n                        ARRIVAL\n           ...
#
#                                         trainNumber
# 0   \n                        150\n
# 1   \n                        150\n
# 2  \n                        8337\n

# %% [markdown]
# ## Vaihe 3
#
# #### Tehtävä 8. Tee SQLite tietokanta ja lisää sinne vaiheen 2 tuloksena saatu dataframe.

# %%
import sqlite3


harkka_base = sqlite3.connect("harkka.db")
connection = harkka_base.cursor()

# %%
table_query="""
CREATE TABLE IF NOT EXISTS train_data (
    actualTime TEXT,
    cancelled TEXT,
    commercialTrack TEXT,
    countryCode TEXT,
    scheduledTime TEXT,
    stationShortCode TEXT,
    stationUICCode TEXT,
    trainStopping TEXT,
    type TEXT,
    trainNumber TEXT
)
"""
connection.execute(table_query)

for row in df.values:
    connection.execute("INSERT INTO train_data VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", tuple(row))

# %%
harkka_base.commit()
harkka_base.close()

print("Data lisätty onnistuneesti")
# Out:
# Data lisätty onnistuneesti
